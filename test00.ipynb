# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def exponential(x,a,b):
    return a*x**b

x = np.linspace(0,5,100)
a = 2
b = 0.5
y = exponential(x,a,b)
plt.plot(x,y)
